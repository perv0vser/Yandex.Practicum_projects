# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Технологический-процесс:" data-toc-modified-id="Технологический-процесс:-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>Технологический процесс:</a></span></li><li><span><a href="#Описание-данных:" data-toc-modified-id="Описание-данных:-0.2"><span class="toc-item-num">0.2&nbsp;&nbsp;</span>Описание данных:</a></span></li><li><span><a href="#Расчёт-эффективности:" data-toc-modified-id="Расчёт-эффективности:-0.3"><span class="toc-item-num">0.3&nbsp;&nbsp;</span>Расчёт эффективности:</a></span></li><li><span><a href="#Метрика-качества:" data-toc-modified-id="Метрика-качества:-0.4"><span class="toc-item-num">0.4&nbsp;&nbsp;</span>Метрика качества:</a></span></li></ul></li><li><span><a href="#1.-Подготовка-данных" data-toc-modified-id="1.-Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>1. Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#1.1.-Откройте-файлы-и-изучите-их." data-toc-modified-id="1.1.-Откройте-файлы-и-изучите-их.-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>1.1. Загрузка и изучение данных.</a></span></li><li><span><a href="#1.2.-Проверьте,-что-эффективность-обогащения-рассчитана-правильно.-Вычислите-её-на-обучающей-выборке-для-признака-rougher.output.recovery.-Найдите-MAE-между-вашими-расчётами-и-значением-признака.-Опишите-выводы." data-toc-modified-id="1.2.-Проверьте,-что-эффективность-обогащения-рассчитана-правильно.-Вычислите-её-на-обучающей-выборке-для-признака-rougher.output.recovery.-Найдите-MAE-между-вашими-расчётами-и-значением-признака.-Опишите-выводы.-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>1.2. Проверим, что эффективность обогащения рассчитана правильно. Вычислим её на обучающей выборке для признака rougher.output.recovery. Найдем MAE между расчётами и значением признака. </a></span></li><li><span><a href="#1.3.-Проанализируйте-признаки,-недоступные-в-тестовой-выборке.-Что-это-за-параметры?-К-какому-типу-относятся?" data-toc-modified-id="1.3.-Проанализируйте-признаки,-недоступные-в-тестовой-выборке.-Что-это-за-параметры?-К-какому-типу-относятся?-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>1.3. Проанализируем признаки, недоступные в тестовой выборке. </a></span></li><li><span><a href="#1.4.-Проведите-предобработку-данных." data-toc-modified-id="1.4.-Проведите-предобработку-данных.-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>1.4. Предобработка данных.</a></span></li></ul></li><li><span><a href="#2.-Анализ-данных" data-toc-modified-id="2.-Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>2. Анализ данных</a></span><ul class="toc-item"><li><span><a href="#2.1.-Посмотрите,-как-меняется-концентрация-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки.-Опишите-выводы." data-toc-modified-id="2.1.-Посмотрите,-как-меняется-концентрация-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки.-Опишите-выводы.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>2.1. Посмотрим, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки. </a></span></li><li><span><a href="#2.2.--Сравните-распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках.-Если-распределения-сильно-отличаются-друг-от-друга,-оценка-модели-будет-неправильной." data-toc-modified-id="2.2.--Сравните-распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках.-Если-распределения-сильно-отличаются-друг-от-друга,-оценка-модели-будет-неправильной.-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>2.2.  Сравним распределения размеров гранул сырья на обучающей и тестовой выборках. </a></span></li><li><span><a href="#2.3.-Исследуйте-суммарную-концентрацию-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах." data-toc-modified-id="2.3.-Исследуйте-суммарную-концентрацию-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах.-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>2.3. Исследуем суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.</a></span></li></ul></li><li><span><a href="#3.-Модель" data-toc-modified-id="3.-Модель-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>3. Модель</a></span><ul class="toc-item"><li><span><a href="#3.1.-Напишите-функцию-для-вычисления-итоговой-sMAPE." data-toc-modified-id="3.1.-Напишите-функцию-для-вычисления-итоговой-sMAPE.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>3.1. Напишем функцию для вычисления итоговой sMAPE.</a></span></li><li><span><a href="#3.2.-Обучите-разные-модели-и-оцените-их-качество-кросс-валидацией.-Выберите-лучшую-модель-и-проверьте-её-на-тестовой-выборке.-Опишите-выводы." data-toc-modified-id="3.2.-Обучите-разные-модели-и-оцените-их-качество-кросс-валидацией.-Выберите-лучшую-модель-и-проверьте-её-на-тестовой-выборке.-Опишите-выводы.-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>3.2. Обучение и выбор лучшей модели

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Требуется подготовить прототип модели машинного обучения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Имеются данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Требуется:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.

# %% [markdown]
# ### Технологический процесс:

# %% [markdown]
# Когда добытая руда проходит первичную обработку, получается дроблёная смесь. Её отправляют на флотацию (обогащение) и двухэтапную очистку.
# Опишем каждую стадию:
# 1. Флотация
#
# Во флотационную установку подаётся смесь золотосодержащей руды. После обогащения получается черновой концентрат и «отвальные хвосты», то есть остатки продукта с низкой концентрацией ценных металлов.
# На стабильность этого процесса влияет непостоянное и неоптимальное физико-химическое состояние флотационной пульпы (смеси твёрдых частиц и жидкости).
#
# 2. Очистка
#
# Черновой концентрат проходит две очистки. На выходе получается финальный концентрат и новые отвальные хвосты.

# %% [markdown]
# ### Описание данных:

# %% [markdown]
# **Технологический процесс**
#
# - Rougher feed — исходное сырье
# - Rougher additions (или reagent additions) — флотационные реагенты: Xanthate, Sulphate, Depressant
# - Xanthate **— ксантогенат (промотер, или активатор флотации);
# - Sulphate — сульфат (на данном производстве сульфид натрия);
# - Depressant — депрессант (силикат натрия).
# - Rougher process (англ. «грубый процесс») — флотация
# - Rougher tails — отвальные хвосты
# - Float banks — флотационная установка
# - Cleaner process — очистка
# - Rougher Au — черновой концентрат золота
# - Final Au — финальный концентрат золота
#
# **Параметры этапов**
#
# - air amount — объём воздуха
# - fluid levels — уровень жидкости
# - feed size — размер гранул сырья
# - feed rate — скорость подачи
#
# **Наименование признаков**
#
# Наименование признаков должно быть такое:
#
# - [этап].[тип_параметра].[название_параметра]
#
# - Пример: rougher.input.feed_ag
#
# Возможные значения для блока [этап]:
#
# - rougher — флотация
# - primary_cleaner — первичная очистка
# - secondary_cleaner — вторичная очистка
# - final — финальные характеристики
#
# Возможные значения для блока [тип_параметра]:
#
# - input — параметры сырья
# - output — параметры продукта
# - state — параметры, характеризующие текущее состояние этапа
# - calculation — расчётные характеристики

# %% [markdown]
# ### Расчёт эффективности:
# Нужно смоделировать процесс восстановления золота из золотосодержащей руды.
# Эффективность обогащения рассчитывается по формуле

# %% [markdown]
# ![Image.png](attachment:Image.png)

# %% [markdown]
# где:
# - C — доля золота в концентрате после флотации/очистки;
# - F — доля золота в сырье/концентрате до флотации/очистки;
# - T — доля золота в отвальных хвостах после флотации/очистки.
# Для прогноза коэффициента нужно найти долю золота в концентратах и хвостах. Причём важен не только финальный продукт, но и черновой концентрат.

# %% [markdown]
# ### Метрика качества:
# Для решения задачи введём новую метрику качества — sMAPE (англ. Symmetric Mean Absolute Percentage Error, «симметричное среднее абсолютное процентное отклонение»).
# Она похожа на MAE, но выражается не в абсолютных величинах, а в относительных. Почему симметричная? Она одинаково учитывает масштаб и целевого признака, и предсказания.
# Метрика sMAPE вычисляется так:

# %% [markdown]
# ![Image%20%281%29.png](attachment:Image%20%281%29.png)

# %% [markdown]
# **Нужно спрогнозировать сразу две величины:**
# - эффективность обогащения чернового концентрата **rougher.output.recovery**;
# - эффективность обогащения финального концентрата **final.output.recovery**.
#
# **Итоговая метрика складывается из двух величин:**

# %% [markdown]
# ![Image%20%282%29.png](attachment:Image%20%282%29.png)

# %% [markdown]
# **Данные находятся в трёх файлах:**
# - gold_recovery_train_new.csv — обучающая выборка;
# - gold_recovery_test_new.csv — тестовая выборка;
# - gold_recovery_full_new.csv — исходные данные.
#
# Данные индексируются датой и временем получения информации (признак date). Соседние по времени параметры часто похожи.
# Некоторые параметры недоступны, потому что замеряются и/или рассчитываются значительно позже. Из-за этого в тестовой выборке отсутствуют некоторые признаки, которые могут быть в обучающей. Также в тестовом наборе нет целевых признаков.
# Исходный датасет содержит обучающую и тестовую выборки со всеми признаками.
# В нашем распоряжении сырые данные: их просто выгрузили из хранилища. Прежде чем приступить к построению модели, потребуется проверить их на корректность.

# %% [markdown]
# ## 1. Подготовка данных

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression, ElasticNet

from sklearn.model_selection import cross_val_score, GridSearchCV 
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, make_scorer
from sklearn.dummy import DummyRegressor

pd.options.mode.chained_assignment=None

#import warnings
#warnings.filterwarnings('ignore')

# %% [markdown]
# ### 1.1. Загрузка и изучение данных.

# %%
# читаем csv-файл и сохраняем в переменную df_full, дату используем, как индекс
try:
    df_full = pd.read_csv('/datasets/gold_recovery_full_new.csv', index_col='date', parse_dates=True)
except:
    df_full = pd.read_csv('https://code.s3.yandex.net/datasets/gold_recovery_full_new.csv', index_col='date', 
                          parse_dates=True) 

df_full.head() # смотрим первые 5 строк из датасета для ознакомления (обычно я смотрб случайные 5, но тут мне интереснее
               # посмотреть на хронологию, а столюцов все равно слишком много, чтобы сразу увидеть что-то интересное)
# Out:
#                      final.output.concentrate_ag  final.output.concentrate_pb  \
# date
# 2016-01-15 00:00:00                     6.055403                     9.889648
# 2016-01-15 01:00:00                     6.029369                     9.968944
# 2016-01-15 02:00:00                     6.055926                    10.213995
# 2016-01-15 03:00:00                     6.047977                     9.977019
# 2016-01-15 04:00:00                     6.148599                    10.142511
#
#                      final.output.concentrate_sol  \
# date
# 2016-01-15 00:00:00                      5.507324
# 2016-01-15 01:00:00                      5.257781
# 2016-01-15 02:00:00                      5.383759
# 2016-01-15 03:00:00                      4.858634
# 2016-01-15 04:00:00                      4.939416
#
#                      final.output.concentrate_au  final.output.recovery  \
# date
# 2016-01-15 00:00:00                    42.192020              70.541216
# ...

# %%
df_full.info() # изучим информацию о данных - форматы адекватные, названия столбцов без CamelCase, а точки в качестве 
               # разделителей идут согласно заданию к проекту, есть пропуски в столбцах
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 19439 entries, 2016-01-15 00:00:00 to 2018-08-18 10:59:59
# Data columns (total 86 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   final.output.concentrate_ag                         19438 non-null  float64
#  1   final.output.concentrate_pb                         19438 non-null  float64
#  2   final.output.concentrate_sol                        19228 non-null  float64
#  3   final.output.concentrate_au                         19439 non-null  float64
#  4   final.output.recovery                               19439 non-null  float64
#  5   final.output.tail_ag                                19438 non-null  float64
#  6   final.output.tail_pb                                19338 non-null  float64
#  7   final.output.tail_sol                               19433 non-null  float64
# ...

# %%
df_full.describe()   # посмотрим описания числовых данных в столбцах
# Out:
#        final.output.concentrate_ag  final.output.concentrate_pb  \
# count                 19438.000000                 19438.000000
# mean                      5.168470                     9.978895
# std                       1.372348                     1.669240
# min                       0.000000                     0.000000
# 25%                       4.251240                     9.137262
# 50%                       5.066094                    10.102433
# 75%                       5.895527                    11.035769
# max                      16.001945                    17.031899
#
#        final.output.concentrate_sol  final.output.concentrate_au  \
# count                  19228.000000                 19439.000000
# mean                       9.501224                    44.076513
# std                        2.787537                     5.129784
# min                        0.000000                     0.000000
# ...

# %% [markdown]
# **Промежуточный вывод:** Несколько беспокоят отрицательные значения параметров уровня воздуха и особенно жидкости во флотационной установке. Преподаватель по проектам ответил, что в проекте нет указаний на то, что это аномалия. Попробуем позже проверить проверить важность данных параметров для модели.

# %%
df_full.corr()
# Out:
#                                             final.output.concentrate_ag  \
# final.output.concentrate_ag                                    1.000000
# final.output.concentrate_pb                                    0.063570
# final.output.concentrate_sol                                   0.380142
# final.output.concentrate_au                                   -0.038373
# final.output.recovery                                          0.185952
# ...                                                                 ...
# secondary_cleaner.state.floatbank5_a_level                     0.184332
# secondary_cleaner.state.floatbank5_b_air                       0.003693
# secondary_cleaner.state.floatbank5_b_level                     0.156471
# secondary_cleaner.state.floatbank6_a_air                       0.162591
# secondary_cleaner.state.floatbank6_a_level                     0.059581
#
#                                             final.output.concentrate_pb  \
# ...

# %% [markdown]
# **Промежуточный вывод:** Затруднительно изучать эту матрицу 86 х 86, тем более нас интересуют, в первую очередь значения, превышающие по модулю 0.7 - 0.8. Попробуем их отсортировать.

# %%
corr_matrix_columns = df_full.columns    #.drop('date', axis=1)
corr_matrix = df_full.corr()
 
for col in corr_matrix_columns:
    print(corr_matrix[col].sort_values(ascending=False))
# Out:
# final.output.concentrate_ag              1.000000
# primary_cleaner.output.concentrate_ag    0.509877
# rougher.input.feed_ag                    0.456279
# final.output.concentrate_sol             0.380142
# final.output.tail_ag                     0.334596
#                                            ...
# primary_cleaner.output.concentrate_pb   -0.152814
# rougher.input.feed_rate                 -0.167154
# primary_cleaner.output.concentrate_au   -0.200367
# rougher.state.floatbank10_a_level       -0.206426
# secondary_cleaner.output.tail_pb        -0.286238
# Name: final.output.concentrate_ag, Length: 86, dtype: float64
# final.output.concentrate_pb              1.000000
# rougher.output.concentrate_pb            0.476002
# primary_cleaner.output.concentrate_pb    0.377527
# final.output.concentrate_au              0.374400
# rougher.input.feed_pb                    0.301446
#                                            ...
# rougher.output.tail_sol                 -0.181719
# ...

# %% [markdown]
# **Промежуточный вывод:** С точки зрения использования линейной модели далее в проекте волнуют риски коллинеарности, а в данных наблюдается немало признаков со значениями коэффициента корреляции выше 0.8 и даже 0.9. Преподаватель по проектам рекомендовал сначала ничего не дропать, а при обучении модели подобрать по сетке регуляционные параметры модели. Так как у модели линейной регрессии в sklearn отсутствуют такие гиперпараметры, он рекомендовал использовать модель ElasticNet() с подбором параметров alpha и l1_ratio. Также около половины параметров с высоким значением корреляции уйдет при удалении из тренировочной выборки фичей, которых нет в тестовой выборке.

# %%
# читаем csv-файл и сохраняем в переменную df_full, дату используем, как индекс
try:
    df_train = pd.read_csv('/datasets/gold_recovery_train_new.csv', index_col='date', parse_dates=True)
except:
    df_train = pd.read_csv('https://code.s3.yandex.net/datasets/gold_recovery_train_new.csv', index_col='date', 
                          parse_dates=True) 

df_train.tail() # смотрим последние 5 строк из датасета для ознакомления
# Out:
#                      final.output.concentrate_ag  final.output.concentrate_pb  \
# date
# 2018-08-18 06:59:59                     3.224920                    11.356233
# 2018-08-18 07:59:59                     3.195978                    11.349355
# 2018-08-18 08:59:59                     3.109998                    11.434366
# 2018-08-18 09:59:59                     3.367241                    11.625587
# 2018-08-18 10:59:59                     3.598375                    11.737832
#
#                      final.output.concentrate_sol  \
# date
# 2018-08-18 06:59:59                      6.803482
# 2018-08-18 07:59:59                      6.862249
# 2018-08-18 08:59:59                      6.886013
# 2018-08-18 09:59:59                      6.799433
# 2018-08-18 10:59:59                      6.717509
#
#                      final.output.concentrate_au  final.output.recovery  \
# date
# 2018-08-18 06:59:59                    46.713954              73.755150
# ...

# %%
df_train.info() # изучим информацию о данных - форматы адекватные, названия столбцов без CamelCase, а точки в качестве 
               # разделителей идут согласно заданию к проекту, есть пропуски в столбцах
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 14149 entries, 2016-01-15 00:00:00 to 2018-08-18 10:59:59
# Data columns (total 86 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   final.output.concentrate_ag                         14148 non-null  float64
#  1   final.output.concentrate_pb                         14148 non-null  float64
#  2   final.output.concentrate_sol                        13938 non-null  float64
#  3   final.output.concentrate_au                         14149 non-null  float64
#  4   final.output.recovery                               14149 non-null  float64
#  5   final.output.tail_ag                                14149 non-null  float64
#  6   final.output.tail_pb                                14049 non-null  float64
#  7   final.output.tail_sol                               14144 non-null  float64
# ...

# %%
# читаем csv-файл и сохраняем в переменную df_test, дату используем, как индекс
try:
    df_test = pd.read_csv('/datasets/gold_recovery_test_new.csv', index_col='date', parse_dates=True)
except:
    df_test = pd.read_csv('https://code.s3.yandex.net/datasets/gold_recovery_test_new.csv', index_col='date', 
                          parse_dates=True) 

df_test.head() # смотрим случайные 5 строк из датасета для ознакомления
# Out:
#                      primary_cleaner.input.sulfate  \
# date
# 2016-09-01 00:59:59                     210.800909
# 2016-09-01 01:59:59                     215.392455
# 2016-09-01 02:59:59                     215.259946
# 2016-09-01 03:59:59                     215.336236
# 2016-09-01 04:59:59                     199.099327
#
#                      primary_cleaner.input.depressant  \
# date
# 2016-09-01 00:59:59                         14.993118
# 2016-09-01 01:59:59                         14.987471
# 2016-09-01 02:59:59                         12.884934
# 2016-09-01 03:59:59                         12.006805
# 2016-09-01 04:59:59                         10.682530
#
#                      primary_cleaner.input.feed_size  \
# date
# 2016-09-01 00:59:59                         8.080000
# 2016-09-01 01:59:59                         8.080000
# 2016-09-01 02:59:59                         7.786667
# 2016-09-01 03:59:59                         7.640000
# ...

# %%
df_test.info() # изучим информацию о данных - форматы адекватные, названия столбцов без CamelCase, а точки в качестве 
               # разделителей идут согласно заданию к проекту, есть пропуски в столбцах
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5290 entries, 2016-09-01 00:59:59 to 2017-12-31 23:59:59
# Data columns (total 52 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   primary_cleaner.input.sulfate               5286 non-null   float64
#  1   primary_cleaner.input.depressant            5285 non-null   float64
#  2   primary_cleaner.input.feed_size             5290 non-null   float64
#  3   primary_cleaner.input.xanthate              5286 non-null   float64
#  4   primary_cleaner.state.floatbank8_a_air      5290 non-null   float64
#  5   primary_cleaner.state.floatbank8_a_level    5290 non-null   float64
#  6   primary_cleaner.state.floatbank8_b_air      5290 non-null   float64
#  7   primary_cleaner.state.floatbank8_b_level    5290 non-null   float64
#  8   primary_cleaner.state.floatbank8_c_air      5290 non-null   float64
# ...

# %% [markdown]
# **Вывод:** Как и сказано в условиях задачи, тестовая выборка содержит меньше столбцов, далее мы рассмотрим, какие именно данные были отброшены.
#
# Типы данных адекватны. Есть фичи с отрицательными значениями, но нет указаний на то, что это аномалии. Есть высоки значения корреляции между разными фичами, на что следует обратить внимание при работе с линейными моделями. В данных есть пропуски. Их не так много в процентном соотношении и мешать это будет только на стадии моделирования, ближе к ней решим, каким образом поступить с пропущенными данными.

# %% [markdown]
# ### 1.2. Проверим, что эффективность обогащения рассчитана правильно. Вычислим её на обучающей выборке для признака rougher.output.recovery. Найдем MAE между расчётами и значением признака.

# %% [markdown]
# ![Image.png](attachment:Image.png)

# %% [markdown]
# где:
# - C — доля золота в концентрате после флотации/очистки;
# - F — доля золота в сырье/концентрате до флотации/очистки;
# - T — доля золота в отвальных хвостах после флотации/очистки.
# Для прогноза коэффициента нужно найти долю золота в концентратах и хвостах. Причём важен не только финальный продукт, но и черновой концентрат.

# %%
# выводим значения искомого столбца
df_train['rougher.output.recovery']
# Out:
# date
# 2016-01-15 00:00:00    87.107763
# 2016-01-15 01:00:00    86.843261
# 2016-01-15 02:00:00    86.842308
# 2016-01-15 03:00:00    87.226430
# 2016-01-15 04:00:00    86.688794
#                          ...
# 2018-08-18 06:59:59    89.574376
# 2018-08-18 07:59:59    87.724007
# 2018-08-18 08:59:59    88.890579
# 2018-08-18 09:59:59    89.858126
# 2018-08-18 10:59:59    89.514960
# Name: rougher.output.recovery, Length: 14149, dtype: float64

# %%
# по формуле считаем эффективность обогащения чернового концентрата rougher.output.recovery
df_train_rougher_calculated_recovery = 100 * \
(df_train['rougher.output.concentrate_au'] * (df_train['rougher.input.feed_au'] - df_train['rougher.output.tail_au'])) / \
(df_train['rougher.input.feed_au'] * (df_train['rougher.output.concentrate_au'] - df_train['rougher.output.tail_au']))

df_train_rougher_calculated_recovery
# Out:
# date
# 2016-01-15 00:00:00    87.107763
# 2016-01-15 01:00:00    86.843261
# 2016-01-15 02:00:00    86.842308
# 2016-01-15 03:00:00    87.226430
# 2016-01-15 04:00:00    86.688794
#                          ...
# 2018-08-18 06:59:59    89.574376
# 2018-08-18 07:59:59    87.724007
# 2018-08-18 08:59:59    88.890579
# 2018-08-18 09:59:59    89.858126
# 2018-08-18 10:59:59    89.514960
# Length: 14149, dtype: float64

# %%
# теперь оценим корректность изначальных расчетов с помощью метрики MAE

mae_df_train_rougher_calculated_recovery = \
mean_absolute_error(df_train_rougher_calculated_recovery, df_train['rougher.output.recovery'])

print(f'Значение средней абсолютной ошибки при расчетах эффективности обогащения: {mae_df_train_rougher_calculated_recovery}')
# Out:
# Значение средней абсолютной ошибки при расчетах эффективности обогащения: 1.1131451184435918e-14

# %% [markdown]
# **Вывод:** Значение отклонения ничтожно мало, так что можем считать рассчет эффективности обогащения корректным.

# %% [markdown]
# ### 1.3. Проанализируем признаки, недоступные в тестовой выборке.

# %%
df_test_columns_dropped = set(df_full.columns) - set(df_test.columns)
display(df_test_columns_dropped)
print(f'Количество столбцов основной выборки, отсутствующих в тестовой: {len(df_test_columns_dropped)}')
# Out:
# {'final.output.concentrate_ag',
#  'final.output.concentrate_au',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_au',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_au',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_au',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
#  'rougher.output.recovery',
# ...

# %% [markdown]
# **Вывод:** В тестовой выборке отсутствуют данные о выходных содержаниях веществ в концентратах и хвостах после каждой из операций (на каждом этапе, тип "параметры продукта"), расчётные характеристики для этапа флотации (которые уж точно не влияют на результат), а также оба целевых признака: эффективность обогащения чернового и финального концентрата (оба также тип "параметры продукта").
#
# Состав фичей в тренировочной выборке потребуется привести в соответствие с тестовой, а в тестовую вернуть целевые признаки для оценки качества модели.

# %% [markdown]
# ### 1.4. Проведите предобработку данных.

# %%
df_full.duplicated().sum() # проверим наличие явных дубликатов в данных
# Out:
# 0

# %%
df_train.duplicated().sum()
# Out:
# 0

# %%
df_test.duplicated().sum()
# Out:
# 0

# %%
df_full.index.value_counts() # даты и время не повторяются, говорить о неявных дубикатах тоже не приходится, а также можно их 
# использовать в качестве индексов, чтобы присоединить столбцы с целевыми признаками из полной выборки к тестовой, не боясь повторений
# Out:
# 2016-04-15 10:00:00    1
# 2016-10-27 22:59:59    1
# 2017-11-26 11:59:59    1
# 2018-07-17 03:59:59    1
# 2017-02-16 03:59:59    1
#                       ..
# 2016-03-03 12:00:00    1
# 2017-07-11 23:59:59    1
# 2017-07-09 15:59:59    1
# 2018-08-15 14:59:59    1
# 2017-07-10 17:59:59    1
# Name: date, Length: 19439, dtype: int64

# %%
df_train.index.value_counts()
# Out:
# 2016-04-15 10:00:00    1
# 2017-06-30 20:59:59    1
# 2017-07-27 10:59:59    1
# 2017-01-09 04:59:59    1
# 2016-06-15 10:59:59    1
#                       ..
# 2018-07-07 23:59:59    1
# 2016-06-29 06:59:59    1
# 2018-03-16 18:59:59    1
# 2017-04-29 01:59:59    1
# 2016-02-02 18:00:00    1
# Name: date, Length: 14149, dtype: int64

# %%
df_test.index.value_counts()
# Out:
# 2016-11-20 05:59:59    1
# 2017-10-21 07:59:59    1
# 2017-10-13 08:59:59    1
# 2017-10-11 03:59:59    1
# 2017-10-15 12:59:59    1
#                       ..
# 2017-12-24 01:59:59    1
# 2016-12-15 07:59:59    1
# 2017-12-17 07:59:59    1
# 2016-10-08 05:59:59    1
# 2016-11-29 06:59:59    1
# Name: date, Length: 5290, dtype: int64

# %%
# добавляем в тест столбцы с целевыми признаками: 
df_test = df_test.join(df_full[['rougher.output.recovery','final.output.recovery']])
df_test.sample(5) # проверяем визуально добавление
# Out:
#                      primary_cleaner.input.sulfate  \
# date
# 2017-09-20 18:59:59                     114.659460
# 2016-10-10 16:59:59                     199.769411
# 2016-10-14 10:59:59                     197.387692
# 2016-11-20 07:59:59                     229.449106
# 2017-11-04 09:59:59                     185.126410
#
#                      primary_cleaner.input.depressant  \
# date
# 2017-09-20 18:59:59                          8.496289
# 2016-10-10 16:59:59                          8.127298
# 2016-10-14 10:59:59                         12.523083
# 2016-11-20 07:59:59                          8.008630
# 2017-11-04 09:59:59                          9.970465
#
#                      primary_cleaner.input.feed_size  \
# date
# 2017-09-20 18:59:59                             6.61
# 2016-10-10 16:59:59                             7.57
# 2016-10-14 10:59:59                             7.35
# 2016-11-20 07:59:59                             7.80
# ...

# %%
df_test.info() # проверяем: было 52 столбца - стало 54 и теперь целевые признаки есть в тестовой выборке
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5290 entries, 2016-09-01 00:59:59 to 2017-12-31 23:59:59
# Data columns (total 54 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   primary_cleaner.input.sulfate               5286 non-null   float64
#  1   primary_cleaner.input.depressant            5285 non-null   float64
#  2   primary_cleaner.input.feed_size             5290 non-null   float64
#  3   primary_cleaner.input.xanthate              5286 non-null   float64
#  4   primary_cleaner.state.floatbank8_a_air      5290 non-null   float64
#  5   primary_cleaner.state.floatbank8_a_level    5290 non-null   float64
#  6   primary_cleaner.state.floatbank8_b_air      5290 non-null   float64
#  7   primary_cleaner.state.floatbank8_b_level    5290 non-null   float64
#  8   primary_cleaner.state.floatbank8_c_air      5290 non-null   float64
# ...

# %% [markdown]
# **Вывод:** Явных и неявных дубликатов не обнаружено. В тестовую выборку добавлены целевые признаки из полной выборки. Для моделирования требуется заполнить пропуски. Пропусков в данных не такой уж большой процент, в целевых признаках их нет. В условиях проекта говорится, что соседние по времени параметры часто похожи, поэтому можно заполнить пропуски, исходя из соседних значений, так как данные идут в хронологии, даже строки тестовой выборки выдернуты не рандомно каждая, а идут единым массивом, вырванным из полной выборки, со своей сохраненной хронологией: используем метод ffil для заполнения пропусков, он заполняет пропуски предыдущим по порядку значением, так как внутренняя хронология в тренировочной и тестовой выборках особо не нарушена, то применим запонение к ним по отдельности, а не к исходной выборке, сделаем это позже, перед шагом моделирования.

# %% [markdown]
# ## 2. Анализ данных

# %% [markdown]
# ### 2.1. Посмотрим, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки.

# %%
# строим графики по 3 металлам с распределениями концентраций по этапам очистки:
plt.figure(figsize=[20, 25])
plt.subplots_adjust(top=0.9, hspace=0.2)
i = 0
for metal in ['au', 'ag', 'pb']:
    i += 1
    plt.subplot(3, 1, i)
    plt.title(f'Распределение концентраций {str(metal)[0].upper()+str(metal)[1]} на различных этапах очистки', fontsize=20)
    plt.hist(df_train[f'rougher.input.feed_{metal}'], bins=50, color='red', edgecolor = 'black', alpha=0.8, 
             label='Исходное сырье')
    plt.hist(df_train[f'rougher.output.concentrate_{metal}'], bins=50, color='purple', edgecolor = 'white', alpha=0.6, 
             label='После флотации')
    plt.hist(df_train[f'primary_cleaner.output.concentrate_{metal}'], bins=50, color='blue', edgecolor = 'black', 
             alpha=0.5, label='После первичной очистки')
    plt.hist(df_train[f'final.output.concentrate_{metal}'], bins=50, color='green', edgecolor = 'white', 
             alpha=0.5, label='Финальный концентрат')
    plt.xlabel('Концентрация металла', fontsize=17)
    plt.xticks(fontsize=15)
    plt.ylabel('Частота', fontsize=17)
    plt.yticks(fontsize=15)
    plt.legend(fontsize=15)
plt.show();

# %% [markdown]
# **Вывод:** Концентрация золота ожидаемо растет с каждым следующим этапом. На финальном этапе данные групируются кучнее вокруг среднего, почти в 2 раза растет частота наблюдений в районе среднего значения, по сравнению с предыдущими этапами. На всех этапах тех процесса есть длинные хвосты с низкими содержаниями металла и есть выбросы с около- или нулевыми концентрациями.
#
# Содержание серебра растет после флотации, после первичной очистки падает примерно до исходного диапазона значений, но распределение уже нормализуется (единый техпроцесс выравнивает разрозненные показатели сырья) и на финальном этапе концентрация металла становится минимальной, что логично, учитывая, что нам нужно получить максимум золота. На всех этапах тех процесса есть длинные хвосты с низкими содержаниями металла и есть выбросы с около- или нулевыми концентрациями.
#
# Содержание свинца значительно увеличивается после флотации, далее еще немного растет после первой очисткии, а после второй не растет в среднем, но распределение нормализуется, в большей степени группируется вокруг средних значений. Возможно рост концентрации свинца как-то связан с хим. процессами, задействованными на этапах производства.

# %% [markdown]
# ### 2.2.  Сравним распределения размеров гранул сырья на обучающей и тестовой выборках.

# %%
# построим график
plt.figure(figsize=(20,15))
sns.distplot(df_train['primary_cleaner.input.feed_size'], hist = False, color='red', kde = True, 
             kde_kws = {'shade': True, 'linewidth': 2}, label='Распределение размеров гранул сырья на обучающей выборке')
sns.distplot(df_test['primary_cleaner.input.feed_size'], hist = False, color='green', kde = True, 
             kde_kws = {'shade': True, 'linewidth': 2}, label='Распределение размеров гранул сырья на тестовой выборке')

# jupiter ругается на distplot, я отключил предупреждения, но если это действительно критично могу поменять на гистограмму
# просто показалось, что формат Shaded Density Plot будет нагляднее в данной ситуации

plt.title('Распределения размеров гранул сырья на обучающей и тестовой выборках', fontsize=20)
plt.xlabel('Размер гранул')
plt.xticks(fontsize=15)
plt.ylabel('Частотность')
plt.yticks(fontsize=15)
plt.legend(fontsize=15)
plt.show();
# Out:
# /Users/sergeypervov/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /Users/sergeypervov/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **Вывод:** Распределения гранул сырья на выборках выглядят похожими, сильных различий не наблюдается, можно применять модель.

# %% [markdown]
# ### 2.3. Исследуем суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.

# %%
# Чтобы не добавлять в датафрейм новые и не нужные в дальнейшем столбцы, для построения распределений суммарной концентрации веществ
# создадим соответствующие суммирующие переменные:
total_elements_concentration_in_rougher_input = 0
total_elements_concentration_in_rougher_output = 0
total_elements_concentration_in_primary_cleaner_output = 0
total_elements_concentration_in_final_output = 0
for element in ['au', 'ag', 'pb', 'sol']:
    total_elements_concentration_in_rougher_input += df_train[f'rougher.input.feed_{element}']
    total_elements_concentration_in_rougher_output += df_train[f'rougher.output.concentrate_{element}']
    total_elements_concentration_in_primary_cleaner_output += df_train[f'primary_cleaner.output.concentrate_{element}']
    total_elements_concentration_in_final_output += df_train[f'final.output.concentrate_{element}']
# построим распределения на одном графике    
plt.figure(figsize=[20, 10])
plt.title('Распределение суммарной концентрации всех веществ на разных стадиях', fontsize=20)
plt.hist(total_elements_concentration_in_rougher_input, bins=50, color='red', edgecolor = 'black', alpha=0.8, 
             label='Исходное сырье')
plt.hist(total_elements_concentration_in_rougher_output, bins=50, color='purple', edgecolor = 'black', alpha=0.6, 
             label='После флотации')
plt.hist(total_elements_concentration_in_primary_cleaner_output, bins=50, color='yellow', edgecolor = 'black', 
             alpha=0.5, label='После первичной очистки')
plt.hist(total_elements_concentration_in_final_output, bins=50, color='green', edgecolor = 'black', alpha=0.4, 
             label='Финальный концентрат')
plt.xlabel('Концентрация веществ', fontsize=17)
plt.xticks(fontsize=15)
plt.ylabel('Частота', fontsize=17)
plt.yticks(fontsize=15)
plt.legend(fontsize=15)
plt.show();

# %%
# Чтобы не добавлять в датафрейм новые и не нужные в дальнейшем столбцы, для построения распределений суммарной концентрации веществ
# создадим соответствующие суммирующие переменные:
total_elements_concentration_in_rougher_input = 0
total_elements_concentration_in_rougher_output = 0
total_elements_concentration_in_primary_cleaner_output = 0
total_elements_concentration_in_final_output = 0
for element in ['au', 'ag', 'pb', 'sol']:
    total_elements_concentration_in_rougher_input += df_train[f'rougher.input.feed_{element}']
    total_elements_concentration_in_rougher_output += df_train[f'rougher.output.concentrate_{element}']
    total_elements_concentration_in_primary_cleaner_output += df_train[f'primary_cleaner.output.concentrate_{element}']
    total_elements_concentration_in_final_output += df_train[f'final.output.concentrate_{element}']
# построим распределения на одном графике    
plt.figure(figsize=[20, 10])
plt.xlim(0, 2)
plt.ylim(0, 400)
plt.title('Распределение суммарной концентрации всех веществ на разных стадиях', fontsize=20)
plt.hist(total_elements_concentration_in_rougher_input, bins=50, color='red', edgecolor = 'black', alpha=0.8, 
             label='Исходное сырье')
plt.hist(total_elements_concentration_in_rougher_output, bins=50, color='purple', edgecolor = 'black', alpha=0.6, 
             label='После флотации')
plt.hist(total_elements_concentration_in_primary_cleaner_output, bins=50, color='yellow', edgecolor = 'black', 
             alpha=0.5, label='После первичной очистки')
plt.hist(total_elements_concentration_in_final_output, bins=50, color='green', edgecolor = 'black', alpha=0.4, 
             label='Финальный концентрат')
plt.xlabel('Концентрация веществ', fontsize=17)
plt.xticks(fontsize=15)
plt.ylabel('Частота', fontsize=17)
plt.yticks(fontsize=15)
plt.legend(fontsize=15)
plt.show();

# %% [markdown]
# **Вывод (дополнен после комментария ревьюера):** Суммарная концентрация всех (4х) веществ растет после флотации, затем откатывает наоловину обратно после первичной очистки и после вторичной опять растет до тех же средних, что и после флотации, но разброс в данных уменьшается, частота наблюдений с близкими к среднему значениями растет примерно в 2 раза. Тут тоже есть длинные хвосты с низкочастотными данными с низкими значениями концентрации и выбросы / аномалии с около- или нулевыми значениями. Удалим их из тренировочной выборки, чтобы улушить качество обучения модели.

# %%
df_train.shape
# Out:
# (14149, 86)

# %%
df_train = df_train[(df_train['rougher.input.feed_au'] + df_train['rougher.input.feed_ag'] + \
                    df_train['rougher.input.feed_pb'] + df_train['rougher.input.feed_sol']) > 2]
display(df_train.shape)
df_train = df_train[(df_train['rougher.output.concentrate_au'] + df_train['rougher.output.concentrate_ag'] + \
                    df_train['rougher.output.concentrate_pb'] + df_train['rougher.output.concentrate_sol']) > 2]
display(df_train.shape)
df_train = df_train[(df_train['primary_cleaner.output.concentrate_au'] + \
           df_train['primary_cleaner.output.concentrate_ag'] + df_train['primary_cleaner.output.concentrate_pb'] + \
           df_train['primary_cleaner.output.concentrate_sol']) > 2]
display(df_train.shape)
df_train = df_train[(df_train['final.output.concentrate_au'] + df_train['final.output.concentrate_ag'] + \
                    df_train['final.output.concentrate_pb'] + df_train['final.output.concentrate_sol']) > 2]
display(df_train.shape)
# Out:
# (13971, 86)
# (13656, 86)
# (13260, 86)
# (13038, 86)

# %% [markdown]
# **Вывод (после комментария ревьюера):** Удалили чуть более 1100 строк с аномалиями, зато модели будет проще обучиться.

# %% [markdown]
# ## 3. Модель

# %% [markdown]
# ### 3.1. Напишите функцию для вычисления итоговой sMAPE.

# %% [markdown]
# ![Image%20%281%29.png](attachment:Image%20%281%29.png)

# %%
def smape(target, predicted):

    smape = 100/len(target) * np.sum(2 * np.abs(target - predicted) / (np.abs(target) + np.abs(predicted) + 1e-6))
    
    return smape

# %% [markdown]
# ![Image%20%282%29.png](attachment:Image%20%282%29.png)

# %%
def total_smape(target, predicted):
    
    target_array = np.array(target)
    target_rougher = target_array[:, 0]
    predicted_rougher = predicted[:, 0]
    target_final = target_array[:, 1]
    predicted_final = predicted[:, 1]
    
    total_smape = 0.25 * smape(target_rougher, predicted_rougher) + \
    0.75 * smape(target_final, predicted_final)
    
    return total_smape

# %% [markdown]
# ### 3.2. Обучение и выбор лучшей модели

# %%
model_columns = df_test.columns
df_train = df_train[model_columns]
df_train = df_train.fillna(method='ffill', axis=0) # заполним пропуски в тренировочной выборке, как описывалось ранее
df_train.reset_index(inplace=True)

# %%
features = df_train.drop(['date','rougher.output.recovery','final.output.recovery'], axis=1)  
target = df_train[['rougher.output.recovery','final.output.recovery']]  # np.array(

# %%
RS = 12345
total_smape_scorer = make_scorer(total_smape, greater_is_better=False)

# %%
linear_parameters = { 'alpha': range(0, 2, 1),
                     'l1_ratio': np.arange(0, 1.1, 0.1) }

linear_cv = GridSearchCV(ElasticNet(random_state=RS), linear_parameters, n_jobs=-1, cv=5, scoring=total_smape_scorer)
linear_cv_df = linear_cv.fit(features, target)
# Out:
# /Users/sergeypervov/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:593: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/sergeypervov/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:593: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/sergeypervov/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# ...

# %%
print(f'Значения лучших регуляционных гиперпараметров для линейной модели: {linear_cv_df.best_params_}')
print(f'Значение среднего итогового sMAPE линейной модели при кросс-валидации: {-round(linear_cv_df.best_score_, 2)}')
# Out:
# Значения лучших регуляционных гиперпараметров для линейной модели: {'alpha': 1, 'l1_ratio': 0.2}
# Значение среднего итогового sMAPE линейной модели при кросс-валидации: 8.58

# %%
linreg = LinearRegression()
total_smape_linreg_scores = cross_val_score(linreg, features, target, scoring=total_smape_scorer, n_jobs=-1, cv=5)
total_smape_linreg_mean = -total_smape_linreg_scores.mean()
print(f'Значение среднего итогового sMAPE линейной регрессии при кросс-валидации: {round(total_smape_linreg_mean, 2)}')
# Out:
# Значение среднего итогового sMAPE линейной регрессии при кросс-валидации: 9.41

# %%
tree_parameters = { 'max_depth': range(1, 11, 1) }
tree_cv = GridSearchCV(DecisionTreeRegressor(random_state=RS), tree_parameters, n_jobs=-1, cv=5, 
                       scoring=total_smape_scorer)
tree_cv_df = tree_cv.fit(features, target)

# %%
print(f'Значение лучшего для дерева решений гиперпараметра {tree_cv_df.best_params_}')
print(f'Значение среднего итогового sMAPE дерева решений при кросс-валидации: {-round(tree_cv_df.best_score_, 2)}')
# Out:
# Значение лучшего для дерева решений гиперпараметра {'max_depth': 3}
# Значение среднего итогового sMAPE дерева решений при кросс-валидации: 8.22

# %%
forest_parameters = { 'n_estimators': range(10, 51, 10),
                     'max_depth': range(1, 11, 1) }
forest_cv = GridSearchCV(RandomForestRegressor(random_state=RS), forest_parameters, n_jobs=-1, cv=5, 
                    scoring=total_smape_scorer)
forest_cv_df = forest_cv.fit(features, target)

# %%
print(f'Значения лучших гиперпараметров для случаного леса: {forest_cv_df.best_params_}')
print(f'Значение среднего итогового sMAPE линейной модели при кросс-валидации: {-round(forest_cv_df.best_score_, 2)}')
# Out:
# Значения лучших гиперпараметров для случаного леса: {'max_depth': 3, 'n_estimators': 20}
# Значение среднего итогового sMAPE линейной модели при кросс-валидации: 8.01

# %% [markdown]
# **Вывод:** Лучшая модель - случайный лес с гиперпараметрами max_depth=3 и n_estimators=20. Проверим ее на тестовой выборке.

# %%
df_test = df_test.fillna(method='ffill', axis=0) # заполним пропуски в тренировочной выборке, как описывалось ранее
df_test.reset_index(inplace=True)

# %%
features_test = df_test.drop(['date','rougher.output.recovery','final.output.recovery'], axis=1)  
target_test = df_test[['rougher.output.recovery','final.output.recovery']]

# %%
predicted_test = forest_cv.best_estimator_.predict(features_test)

print(f'Значение итогового sMAPE случайного леса с лучшими гиперпараметрами на тестовой выборке: \
      {round(total_smape(target_test, predicted_test), 2)}')
# Out:
# Значение итогового sMAPE случайного леса с лучшими гиперпараметрами на тестовой выборке:       8.82

# %%
dummy = DummyRegressor(strategy='median')

dummy.fit(features, target)

predicted_dummy = dummy.predict(features_test)


print(f'Значение итогового sMAPE константной модели, выдающей всегда медиану значений тренировочного таргета: \
      {round(total_smape(target_test, predicted_dummy), 2)}')
# Out:
# Значение итогового sMAPE константной модели, выдающей всегда медиану значений тренировочного таргета:       9.35

# %% [markdown]
# **Вывод:** Выбранная модель хорошо показала себя на тестовой выборке. Метрика sMAPE на выбранной модели лучше, чем на константной модели.
